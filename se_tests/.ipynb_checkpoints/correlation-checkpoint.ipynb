# %% [markdown]
# #### Setup variables

# %%
n_mels = 64
frame_width = 0.04
hop_width = 0.02
epochs = 100
clip_length = 10 #s
sequence_length = int(clip_length/hop_width) # 10s/0.02s=500 frames
fs = 44100 #Hz
dropout = 0.3
conv_filters = 128
gru_units = 32
epochs = 100
learning_rate = 0.001

# %%
order = ['(object) banging',
 'cupboard',
 'drawer',
 '(object) snapping',
 'glass jingling',
 'cutlery',
 'children shouting',
 'dishes',
 '(object) rustling',
 'wind blowing',
 'object impact',
 'water tap running',
 'people walking',
 'washing dishes',
 'people speaking',
 'car passing by',
 'bird singing']

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)
print(data)
# Out:
#                  event        SF        SE  mean_zcr
# 0    water tap running  0.054574  0.735412  0.168011
# 1               dishes  0.020023  0.654973  0.133267
# 2               dishes  0.034678  0.688673  0.135098
# 3               dishes  0.037825  0.673155  0.132183
# 4               dishes  0.053950  0.718296  0.165982
# ..                 ...       ...       ...       ...
# 777       wind blowing  0.001154  0.256570  0.010574
# 778       wind blowing  0.000653  0.203960  0.008787
# 779       bird singing  0.000180  0.160133  0.007050
# 780       wind blowing  0.000173  0.158925  0.006699
# 781       bird singing  0.000206  0.154811  0.004865
#
# [782 rows x 4 columns]

# %%
from scipy.stats import pearsonr
import numpy as np

plt.scatter(data.event,data.SE)
plt.xticks(rotation=90)


# # Calculate Pearson correlation coefficient
# correlation, _ = pearsonr(data.event,data.SE)
# print("Pearson correlation coefficient:", correlation)

# plt.xticks(rotation=90)
# plt.xticks(range(1, len(order) + 1), order)


# # Fit a linear regression line
# m, b = np.polyfit(data.event,data.SE1,)
# plt.plot(x, m*np.array(x) + b, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jf/qwg9zxqs3zq4vjytsnxgmvd80000gn/T/ipykernel_3451/4169268839.py in <module>
#       6 exit(0)
#       7 # Calculate Pearson correlation coefficient
# ----> 8 correlation, _ = pearsonr(data.event,data.SE)
#       9 print("Pearson correlation coefficient:", correlation)
#      10
#
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    4027     # that the data type is at least 64 bit floating point.  It might have
#    4028     # more precision if the input is, for example, np.longdouble.
# -> 4029     dtype = type(1.0 + x[0] + y[0])
#    4030
#    4031     if n == 2:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# ### SE boxplot final

# %%
data = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)
print(data)


order_df = data.groupby(["event"])
order = order_df.median()["SE"].sort_values().index

import seaborn as sns
# Set up the plot
plt.figure(figsize=(10, 6))
# use order=event_lengths.event_label instead of order=order to order by event lengths
sns.boxplot(x = 'event', y = 'SE', data = data,order=event_lengths.event_label)

# Customize the plot
plt.xlabel('Sound Event')
plt.ylabel('Mean Spectral Entropy')
plt.title('Mean Spectral Entropy per Sound Event')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.yscale('log') 

plt.show()

# %% [markdown]
# ### ZCR boxplot final

# %%
data = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)
print(data)

order_df = data.groupby(["event"])
order = order_df.median()["mean_zcr"].sort_values().index

import seaborn as sns
# Set up the plot
plt.figure(figsize=(10, 6))
# use order=event_lengths.event_label instead of order=order to order by event lengths
sns.boxplot(x = 'event', y = 'mean_zcr', data = data,order=event_lengths.event_label)

# Customize the plot
plt.xlabel('Sound Event')
plt.ylabel('Mean Zero Crossing Rate')
plt.title('Mean  Zero Crossing Rate per Sound Event')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
# plt.yscale('log') 
plt.show()
