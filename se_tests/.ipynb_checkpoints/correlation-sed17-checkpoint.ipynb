# %% [markdown]
# #### Setup variables

# %%
n_mels = 64
frame_width = 0.04
hop_width = 0.02
epochs = 100
clip_length = 10 #s
sequence_length = int(clip_length/hop_width) # 10s/0.02s=500 frames
fs = 44100 #Hz
dropout = 0.3
conv_filters = 128
gru_units = 32
epochs = 100
learning_rate = 0.001

# %%
order = ['(object) banging',
 'cupboard',
 'drawer',
 '(object) snapping',
 'glass jingling',
 'cutlery',
 'children shouting',
 'dishes',
 '(object) rustling',
 'wind blowing',
 'object impact',
 'water tap running',
 'people walking',
 'washing dishes',
 'people speaking',
 'car passing by',
 'bird singing']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)

# Sort the DataFrame by the given row order
df_sorted = df.sort_values(by='event', key=lambda x: x.map(dict(zip(order, range(len(order))))))

# Reset the index if necessary
df_sorted = df_sorted.reset_index(drop=True)

# Print the sorted DataFrame
print(df_sorted)

# print(data)
# Out:
#                 event        SF        SE  mean_zcr
# 0    (object) banging  0.002926  0.404599  0.024472
# 1    (object) banging  0.000305  0.341796  0.017478
# 2    (object) banging  0.000823  0.267726  0.010067
# 3    (object) banging  0.000514  0.303931  0.010463
# 4    (object) banging  0.000649  0.519152  0.037147
# ..                ...       ...       ...       ...
# 777      bird singing  0.001127  0.345384  0.015928
# 778      bird singing  0.001773  0.322191  0.012371
# 779      bird singing  0.001024  0.273770  0.011792
# 780      bird singing  0.003125  0.448863  0.022029
# 781      bird singing  0.000206  0.154811  0.004865
#
# [782 rows x 4 columns]

# %%
from scipy.stats import pearsonr
import numpy as np

plt.scatter(df_sorted.event,df_sorted.SE)
plt.xticks(rotation=90)

x = pd.factorize(df_sorted['event'])[0]
y = df_sorted.SE

# Perform linear regression
m, b = np.polyfit(x, y, 1)

# Generate points for the line of best fit
x_line = np.linspace(min(x), max(x), 100)
y_line = m * x_line + b

# Create a scatter plot of the data
plt.scatter(x, y)

# Plot the line of best fit
plt.plot(x_line, y_line, color='red')

# Set labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')

# Show the plot
plt.show()

# Calculate Pearson correlation coefficient and p-value
correlation, p_value = pearsonr(x, y)
print("Pearson correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: -0.272139703686243
# p-value: 9.584772452628646e-15

# %% [markdown]
# ### SE boxplot final

# %%
data = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)
print(data)


order_df = data.groupby(["event"])
order = order_df.median()["SE"].sort_values().index

import seaborn as sns
# Set up the plot
plt.figure(figsize=(10, 6))
# use order=event_lengths.event_label instead of order=order to order by event lengths
sns.boxplot(x = 'event', y = 'SE', data = data,order=order)

# Customize the plot
plt.xlabel('Sound Event')
plt.ylabel('Mean Spectral Entropy')
plt.title('Mean Spectral Entropy per Sound Event')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
# plt.yscale('log') 

plt.show()
# Out:
#                  event        SF        SE  mean_zcr
# 0    water tap running  0.054574  0.735412  0.168011
# 1               dishes  0.020023  0.654973  0.133267
# 2               dishes  0.034678  0.688673  0.135098
# 3               dishes  0.037825  0.673155  0.132183
# 4               dishes  0.053950  0.718296  0.165982
# ..                 ...       ...       ...       ...
# 777       wind blowing  0.001154  0.256570  0.010574
# 778       wind blowing  0.000653  0.203960  0.008787
# 779       bird singing  0.000180  0.160133  0.007050
# 780       wind blowing  0.000173  0.158925  0.006699
# 781       bird singing  0.000206  0.154811  0.004865
#
# [782 rows x 4 columns]

# %% [markdown]
# ### ZCR boxplot final

# %%
data = pd.read_csv('../signal_test_antropy_normalized0db_zcr.csv',index_col=False)
print(data)

order_df = data.groupby(["event"])
order = order_df.median()["mean_zcr"].sort_values().index

import seaborn as sns
# Set up the plot
plt.figure(figsize=(10, 6))
# use order=event_lengths.event_label instead of order=order to order by event lengths
sns.boxplot(x = 'event', y = 'mean_zcr', data = data,order=order)

# Customize the plot
plt.xlabel('Sound Event')
plt.ylabel('Mean Zero Crossing Rate')
plt.title('Mean  Zero Crossing Rate per Sound Event')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
# plt.yscale('log') 
plt.show()
# Out:
#                  event        SF        SE  mean_zcr
# 0    water tap running  0.054574  0.735412  0.168011
# 1               dishes  0.020023  0.654973  0.133267
# 2               dishes  0.034678  0.688673  0.135098
# 3               dishes  0.037825  0.673155  0.132183
# 4               dishes  0.053950  0.718296  0.165982
# ..                 ...       ...       ...       ...
# 777       wind blowing  0.001154  0.256570  0.010574
# 778       wind blowing  0.000653  0.203960  0.008787
# 779       bird singing  0.000180  0.160133  0.007050
# 780       wind blowing  0.000173  0.158925  0.006699
# 781       bird singing  0.000206  0.154811  0.004865
#
# [782 rows x 4 columns]
